# %% [markdown]
# # Table Preview – Car Workshop
#
# One cell per table: `SELECT * ... LIMIT 100`. Quick eyeball check of
# every table in the `car_workshop` catalog. Read-only – safe to run all.

# %% [markdown]
# ## dim

# %%
# %sql
SELECT * FROM car_workshop.dim.dim_locations LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.dim.dim_employees LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.dim.dim_customers LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.dim.dim_vehicles LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.dim.dim_products LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.dim.dim_services LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.dim.dim_suppliers LIMIT 100

# %% [markdown]
# ## fact

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_work_orders LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_work_order_items LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_sales_transactions LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_sales_items LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_invoices LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_payments LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_inventory_movements LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_appointments LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_purchase_orders LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_purchase_order_items LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_customer_feedback LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_loyalty_program LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.fact.fact_employee_schedules LIMIT 100

# %% [markdown]
# ## silver

# %%
# %sql
SELECT * FROM car_workshop.silver.sales_transactions LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.silver.sales_transactions_quarantine LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.silver.sales_items LIMIT 100

# %%
# %sql
SELECT * FROM car_workshop.silver.sales_items_quarantine LIMIT 100
