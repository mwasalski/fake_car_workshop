# %% [markdown]
# # DESCRIBE EXTENDED – fake_car_workshop
#
# Runs `DESCRIBE EXTENDED` for every table in the catalog.
# Set the catalog name in the widget below before running.

# %%
# Widget – set catalog name before running
dbutils.widgets.text('catalog', 'fake_car_workshop_franchise', 'Catalog')
CATALOG = dbutils.widgets.get('catalog')

print(f'Catalog: {CATALOG}')
print(f'dim  schema: {CATALOG}.dim')
print(f'fact schema: {CATALOG}.fact')

# %% [markdown]
# ## Dimension Tables

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_customers')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_customers'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_employees')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_employees'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_locations')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_locations'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_products')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_products'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_services')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_services'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_suppliers')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_suppliers'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_vehicles')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.dim.dim_vehicles'))

# %% [markdown]
# ## Fact Tables

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_appointments')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_appointments'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_customer_feedback')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_customer_feedback'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_employee_schedules')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_employee_schedules'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_inventory_movements')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_inventory_movements'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_invoices')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_invoices'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_loyalty_program')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_loyalty_program'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_payments')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_payments'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_purchase_order_items')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_purchase_order_items'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_purchase_orders')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_purchase_orders'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_sales_items')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_sales_items'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_sales_transactions')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_sales_transactions'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_work_order_items')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_work_order_items'))

# %%
print('=' * 60)
print(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_work_orders')
print('=' * 60)
display(spark.sql(f'DESCRIBE EXTENDED {CATALOG}.fact.fact_work_orders'))
